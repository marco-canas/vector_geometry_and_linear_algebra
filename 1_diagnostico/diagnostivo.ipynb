# %% [markdown]
# Dame un diseño de primera clase o encuentro para realizar el 5 de agosto de 2025 con los estudiantes de Ingeniería agropecuaria, donde en esta clase realicemos el diagnóstico de características: ### 1. **Diagnóstico o Identificación del Problema**

# %% [markdown]
# # **Diseño de Primera Clase: Diagnóstico de Habilidades y Presaberes para Álgebra Lineal con Python**
# **Enfoque:** Investigación Acción Educativa (IAE)
# **Duración:** 2 horas
#
# ---

# %% [markdown]
# ## **1. Diagnóstico: Identificación del Problema**
# ### **¿Qué ocurre? ¿Por qué es un problema?**
# **Situación observada:**
# - Estudiantes de Ingeniería Agropecuaria presentan **heterogeneidad en habilidades matemáticas y computacionales**, lo que dificulta el aprendizaje de álgebra lineal aplicada a ciencia de datos agrícolas.
# - **Falta de estandarización** en el acceso a herramientas tecnológicas (Python, Jupyter, VS Code).
#
# **Objetivo del diagnóstico:**
# - Identificar niveles de dominio en:
#   - Conceptos básicos de álgebra lineal (vectores, matrices).
#   - Sintaxis Python y manejo de entornos (Anaconda, VS Code).
#   - Acceso a recursos tecnológicos.
#
# ---

# %% [markdown]
# ## **2. Actividades de Diagnóstico**
# ### **A. Encuesta Inicial (30 min)**
# **Herramienta:** Formulario Google Forms o Mentimeter.
# **Preguntas clave:**
#
# 1. **Habilidades Matemáticas:**
#    - "¿Has trabajado con matrices o sistemas de ecuaciones lineales? (Nada/Básico/Intermedio/Avanzado)".
#    - "Menciona un problema agrícola donde creas que se podrían aplicar matrices".
#
# 2. **Recursos Tecnológicos:**
#    - "¿Tienes acceso a un computador personal? (Sí/No)".
#    - "¿Has usado Jupyter Notebook o VS Code? (Sí/No)".
#
# 3. **Experiencia con Python:**
#    - "Escribe un ejemplo de cómo definirías una matriz en Python (si no sabes, déjalo en blanco)".
#
# **Ejemplo de pregunta con código:**
# ```python
# # ¿Qué hace este código? (Opción múltiple)
# import numpy as np
# A = np.array([[1, 2], [3, 4]])
# print(A.shape)
# ```
# *Opciones:* a) Suma la matriz, b) Imprime las dimensiones, c) Calcula la inversa.
#
# ---
#
# ### **B. Ejercicio Práctico Rápido (45 min)**
# **Objetivo:** Evaluar habilidades básicas de Python y álgebra lineal.
#
# 1. **Instalación Guiada (15 min):**
#    - Verificar instalación de:
#      - Anaconda/Jupyter Notebook.
#      - VS Code con extensión Python.
#    - *Alternativa:* Usar Google Colab si no hay recursos locales.
#
# 2. **Tarea de Código (30 min):**
#    - **Actividad:** Resolver un sistema lineal simple relacionado con balance de nutrientes en suelos.
#    ```python
#    # Ejemplo en Jupyter Notebook
#    import numpy as np
#    # Sistema: 2x + y = 5, x - y = 1
#    A = np.array([[2, 1], [1, -1]])
#    b = np.array([5, 1])
#    solucion = np.linalg.solve(A, b)
#    print("Gramos de Nitrógeno (x) y Fósforo (y):", solucion)
#    ```
#    - **Indicador de logro:**
#      - 70% de estudiantes ejecuta el código sin errores.
#
# ---
#
# ## **3. Análisis de Resultados**
# ### **Participación Activa (45 min)**
# 1. **Discusión Grupal:**
#    - "¿Qué dificultades encontraron al escribir código?" (Errores comunes: sintaxis, instalación).
#    - "¿Cómo creen que el álgebra lineal puede optimizar el uso de fertilizantes?".
#
# 2. **Mapa Conceptual Colectivo:**
#    - Pizarra colaborativa (Miro o Jamboard) con:
#      - **Problemas agrícolas identificados** (ej: predicción de cosechas).
#      - **Herramientas tecnológicas necesarias** (Python, sensores IoT).
#
# ---
#
# ## **4. Plan de Acción**
# ### **Adaptaciones Basadas en el Diagnóstico**
# - **Nivel Bajo en Python:**
#   - Taller remedial de sintaxis Python (2 horas extracurriculares).
#   - Tutoriales interactivos en [DataCamp](https://www.datacamp.com/).
# - **Falta de Recursos:**
#   - Asignar tiempos de laboratorio con computadores institucionales.
#   - Uso de Google Colab para evitar instalaciones locales.
#
# ---
#
# ## **5. Evaluación del Diagnóstico**
# **Instrumento:** Rúbrica de habilidades iniciales.
#
# | **Habilidad**               | **Nivel (1-5)** | **Evidencia**                  |
# |-----------------------------|-----------------|--------------------------------|
# | Sintaxis Python básica      |       3         | Ejercicio de matrices ejecutado |
# | Acceso a herramientas       |       4         | Encuesta completada            |
# | Comprensión de aplicaciones |       2         | Participación en discusión     |
#
# ---
#
# ## **Materiales Adicionales**
# - **Video introductorio:** "¿Por qué Álgebra Lineal en la Agricultura?" (ejemplo: [YouTube](https://www.youtube.com/watch?v=example)).
# - **Plantilla Jupyter Notebook:** [Descargar desde GitHub](https://github.com/udea-agroalgebra/notebooks).
#
# **Nota:** Esta clase sigue el ciclo **IAE** (Observación → Diagnóstico → Acción → Evaluación) y se ajusta a las necesidades del Campus Caucasia .
