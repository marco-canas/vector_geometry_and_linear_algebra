# %% [markdown]
# # Rúbrica para la presentación de parciales en video
#
# 1. Cada propiedad que enuncie, debe ser capaz de presentar su verificación con ejemplos sencillos en lenguaje Python.
#      - Si muestra que la suma de vectores es conmutativa, muestre un ejemplo con dos vectores específicos que al
#        reordenar los vectores, el resultado es el mismo.
# 2. Cada operación que presente debe estar acompañada de un ejemplo en Python que demuestre su capacidad de realizar la operación y de interpretar su resultado.
# 3. Si habla de transformaciones lineales, debe mostrar un ejemplo de una transformación lineal específica (por ejemplo, una rotación o una reflexión) y cómo se aplica a un vector o conjunto de vectores.
# 4.
